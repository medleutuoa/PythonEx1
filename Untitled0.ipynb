# %% [markdown]
# <a href="https://colab.research.google.com/github/medleutuoa/PythonEx1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/εγκλήματα_πολέμου.csv", sep=';',  on_bad_lines='skip')
df = df.dropna(axis=1, how='all')
df
# Out:
#      type           source                                              title  \
# 0     web     timesnews.gr  Σέβη Βολουδάκη: Η εμπορία ανθρώπων δεν είναι α...
# 1     web  sofokleousin.gr  Ανδρουλάκης: «Πρέπει άμεσα να τελειώσει η εθνο...
# 2     web        ekriti.gr  ΟΗΕ: Ξέσπασε σε κλάματα ο πρεσβευτής της Παλαι...
# 3     web    iefimerida.gr  Γλυκερία: Αποκλείστηκε από συναυλία του ΚΚΕ γι...
# 4     web       news247.gr  Ανδρουλάκης: Πρέπει άμεσα να τελειώσει η εθνοκ...
# ...   ...              ...                                                ...
# 4995  web   moneyreview.gr  Εκτός λίστας οι ΗΠΑ για τουρίστες χωρών που «χ...
# 4996  web          real.gr  Τσουκαλάς: «Στάχτη στα μάτια των πολιτών η πρό...
# 4997  web   prismaradio.gr  Κουτσούμπας κατά ΠΑΣΟΚ: Ράβει κοστούμι συγκυβέ...
# 4998  web           cnn.gr  Λωρίδα της Γάζας: Σχεδόν 180.000 άτομα εκτοπίσ...
# 4999  web           cnn.gr  Το Ουκρανικό κυριάρχησε στο τετ α τετ Λαβρόφ -...
#
# ...

# %%
df(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c6101a930cf2> in <cell line: 0>()
# ----> 1 df(index)
#
# NameError: name 'index' is not defined

# %%
df.columns
# Out:
# Index(['type', 'source', 'title', 'text', 'categories', 'sentiment', 'date',
#        'time', 'link'],
#       dtype='object')

# %%
df["source"].unique()
# Out:
# array(['timesnews.gr', 'sofokleousin.gr', 'ekriti.gr', 'iefimerida.gr',
#        'news247.gr', 'thebest.gr', 'amna.gr', 'protagon.gr', 'in.gr',
#        'newsbeast.gr', 'iapogevmatini.gr', 'radiovera.gr',
#        'gr.euronews.com', 'formedia.gr', 'iapopsi.gr', 'enanews.gr',
#        'enikos.gr', 'best-tv.gr', 'el.gr', 'radiosecret.gr',
#        'reporter.gr', 'amarysia.gr', 'emakedonia.gr', 'ergasianews.gr',
#        'slpress.gr', 'privateinsurance.gr', 'bankingnews.gr',
#        'ieidiseis.gr', 'popaganda.gr', '94fm.gr', 'ertnews.gr',
#        'tovima.gr', 'voria.gr', 'ogdoo.gr', 'oparlapipas.gr',
#        'ant1news.gr', 'thestival.gr', 'antenna.gr', 'pentapostagma.gr',
#        'pronews.gr', 'neakriti.gr', 'vipnews.gr', 'tvxs.gr', 'neamou.gr',
#        'glow.gr', 'nicemagazine.gr', 'capital.gr', 'newsbomb.gr',
#        'sei.gr', 'agrinio24.gr', 'achaianews.gr', 'ellinikahoaxes.gr',
#        'crisismonitor.gr', 'creta24.gr', 'parallaximag.gr',
# ...

# %%
df.source.nunique()
# Out:
# 628

# %%
sorted(list(df["source"].unique()))#[:10]
# Out:
# ['1069.gr',
#  '12nisospress.com',
#  '15minutes.gr',
#  '1voice.gr',
#  '902.gr',
#  '94fm.gr',
#  'aagora.gr',
#  'achaianews.gr',
#  'adieksodos.gr',
#  'adologala.gr',
#  'aegeanews.gr',
#  'aek365.org',
#  'aeolos.tv',
#  'afirimeno.com',
#  'aftodioikisi.gr',
#  'agon.gr',
#  'agonaskritis.gr',
#  'agrinio24.gr',
#  'agrinionews.gr',
#  'agriniopress.gr',
#  'agrocapital.gr',
#  'agronews.gr',
#  'aigiovoice.gr',
#  'alfavita.gr',
#  'alithia.gr',
#  'alithianews.gr',
#  'allabouthealth.gr',
#  'alphafreepress.gr',
#  'alphatv.gr',
#  'alt.gr',
#  'amarysia.gr',
#  'amarysianotia.gr',
#  'amna.gr',
#  'anatolh.com',
#  'anatropinews.gr',
#  'anexartitos.gr',
#  'anexarttitosblog.gr',
#  'anoixtoparathyro.gr',
#  'ant1news.gr',
#  'antarsya.gr',
#  'antenna.gr',
#  'anticorr.gr',
#  'antinews.gr',
#  'apopsilive.gr',
#  'apotis4stis5.com',
#  'arcadiaportal.gr',
#  'ardin-rixi.gr',
#  'argolidaportal.gr',
#  'argolika.gr',
#  'argolikeseidhseis.gr',
#  'aromalefkadas.gr',
# ...

# %%
df.groupby("source")['title'].count().reset_index().sort_values("title",ascending=False).head(20)
# Out:
#                source  title
# 466        politic.gr     72
# 56       athina984.gr     67
# 189        ertnews.gr     64
# 386   naftemporiki.gr     63
# 275             in.gr     62
# 442   parapolitika.gr     60
# 64     bankingnews.gr     55
# 488     protothema.gr     53
# 299    kathimerini.gr     53
# 32            amna.gr     50
# 518           skai.gr     48
# 579      topontiki.gr     47
# 126  documentonews.gr     47
# 84         capital.gr     45
# 502    rizospastis.gr     45
# 192         ethnos.gr     45
# 262     iefimerida.gr     43
# 580         tovima.gr     43
# 277      indicator.gr     42
# 403      newsbeast.gr     42

# %%
df[df["source"]=="politic.gr"]
# Out:
#      type      source                                              title  \
# 149   web  politic.gr  Ανοιχτή αντιπαράθεση του Πιρς Μόργκαν με την π...
# 236   web  politic.gr  «Χαϊδεύουν τα μαλλιά τους και ζητούν συγγνώμη ...
# 262   web  politic.gr  Κάλεσμα για διακοπή πωλήσεων όπλων στο Ισραήλ ...
# 293   web  politic.gr  Διασημότητες ζητούν από το Λονδίνο να σταματήσ...
# 327   web  politic.gr  Νέα πρόταση για κατάπαυση του πυρός στη Γάζα α...
# ...   ...         ...                                                ...
# 4797  web  politic.gr  Αλέξης Τσίπρας: Άμεσες κυρώσεις κατά του Ισραή...
# 4854  web  politic.gr  Τσίπρας για Γάζα: Απαραίτητη η επιβολή κυρώσεω...
# 4857  web  politic.gr  Σχεδόν 180.000 άνθρωποι εκτοπίστηκαν από τις ν...
# 4858  web  politic.gr  Γαλλία: 300 συγγραφείς καταδικάζουν τη γενοκτο...
# 4930  web  politic.gr  Γάζα: Οι θάνατοι ξεπέρασαν τις 54.000, σύμφωνα...
#
#                                                    text categories sentiment  \
# ...

# %%
politic_df = df[df["source"]=="politic.gr"]
politic_df = politic_df.reset_index(drop=True)
politic_df
# Out:
#    type      source                                              title  \
# 0   web  politic.gr  Ανοιχτή αντιπαράθεση του Πιρς Μόργκαν με την π...
# 1   web  politic.gr  «Χαϊδεύουν τα μαλλιά τους και ζητούν συγγνώμη ...
# 2   web  politic.gr  Κάλεσμα για διακοπή πωλήσεων όπλων στο Ισραήλ ...
# 3   web  politic.gr  Διασημότητες ζητούν από το Λονδίνο να σταματήσ...
# 4   web  politic.gr  Νέα πρόταση για κατάπαυση του πυρός στη Γάζα α...
# ..  ...         ...                                                ...
# 67  web  politic.gr  Αλέξης Τσίπρας: Άμεσες κυρώσεις κατά του Ισραή...
# 68  web  politic.gr  Τσίπρας για Γάζα: Απαραίτητη η επιβολή κυρώσεω...
# 69  web  politic.gr  Σχεδόν 180.000 άνθρωποι εκτοπίστηκαν από τις ν...
# 70  web  politic.gr  Γαλλία: 300 συγγραφείς καταδικάζουν τη γενοκτο...
# 71  web  politic.gr  Γάζα: Οι θάνατοι ξεπέρασαν τις 54.000, σύμφωνα...
#
#                                                  text categories sentiment  \
# ...

# %%
selected_sites = ['politic.gr', 'ertnews.gr', 'in.gr', 'naftemporiki.gr', 'athina984.gr']
filtered_df = df[df['source'].isin(selected_sites)]
filtered_df.reset_index(drop=True, inplace=True)
filtered_df = filtered_df.sort_values("source").reset_index(drop=True)
filtered_df
# Out:
#     type        source                                              title  \
# 0    web  athina984.gr                         Δελτίο Ειδήσεων στις 07:00
# 1    web  athina984.gr  ΟΗΕ: Οι Παλαιστίνιοι της Γάζας αξίζουν “περισσ...
# 2    web  athina984.gr                         Δελτίο ειδήσεων στις 18:00
# 3    web  athina984.gr                         Δελτίο ειδήσεων στις 12:00
# 4    web  athina984.gr  Βέβαιος ότι το Βερολίνο θα παραδώσει Taurus στ...
# ..   ...           ...                                                ...
# 323  web    politic.gr  Νέα Αριστερά: Η αλληλεγγύη προς την Παλαιστίνη...
# 324  web    politic.gr  Μέλη της Νέας Αριστεράς ανήρτησαν τη σημαία τη...
# 325  web    politic.gr  Καταιγίδα αντιδράσεων για τη Φουρέιρα μετά τη ...
# 326  web    politic.gr  Στρατηγική συνεργασία Γερμανίας – Ουκρανίας γι...
# 327  web    politic.gr  Πάπας Λέων ο ΙΔ’: Ο θρήνος από τις μητέρες της...
#
#                                                   text categories sentiment  \
# ...

# %%
filtered_df["source"].unique()
# Out:
# array(['athina984.gr', 'ertnews.gr', 'in.gr', 'naftemporiki.gr',
#        'politic.gr'], dtype=object)

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/εγκλήματα_πολέμου.csv", sep=';',  on_bad_lines='skip')
df2
# Out:
#      type           source                                              title  \
# 0     web     timesnews.gr  Σέβη Βολουδάκη: Η εμπορία ανθρώπων δεν είναι α...
# 1     web  sofokleousin.gr  Ανδρουλάκης: «Πρέπει άμεσα να τελειώσει η εθνο...
# 2     web        ekriti.gr  ΟΗΕ: Ξέσπασε σε κλάματα ο πρεσβευτής της Παλαι...
# 3     web    iefimerida.gr  Γλυκερία: Αποκλείστηκε από συναυλία του ΚΚΕ γι...
# 4     web       news247.gr  Ανδρουλάκης: Πρέπει άμεσα να τελειώσει η εθνοκ...
# ...   ...              ...                                                ...
# 4995  web   moneyreview.gr  Εκτός λίστας οι ΗΠΑ για τουρίστες χωρών που «χ...
# 4996  web          real.gr  Τσουκαλάς: «Στάχτη στα μάτια των πολιτών η πρό...
# 4997  web   prismaradio.gr  Κουτσούμπας κατά ΠΑΣΟΚ: Ράβει κοστούμι συγκυβέ...
# 4998  web           cnn.gr  Λωρίδα της Γάζας: Σχεδόν 180.000 άτομα εκτοπίσ...
# 4999  web           cnn.gr  Το Ουκρανικό κυριάρχησε στο τετ α τετ Λαβρόφ -...
#
# ...

# %%
all_df = pd.concat([df, df2], axis=0, ignore_index=True)
all_df
# Out:
#      type           source                                              title  \
# 0     web     timesnews.gr  Σέβη Βολουδάκη: Η εμπορία ανθρώπων δεν είναι α...
# 1     web  sofokleousin.gr  Ανδρουλάκης: «Πρέπει άμεσα να τελειώσει η εθνο...
# 2     web        ekriti.gr  ΟΗΕ: Ξέσπασε σε κλάματα ο πρεσβευτής της Παλαι...
# 3     web    iefimerida.gr  Γλυκερία: Αποκλείστηκε από συναυλία του ΚΚΕ γι...
# 4     web       news247.gr  Ανδρουλάκης: Πρέπει άμεσα να τελειώσει η εθνοκ...
# ...   ...              ...                                                ...
# 9995  web   moneyreview.gr  Εκτός λίστας οι ΗΠΑ για τουρίστες χωρών που «χ...
# 9996  web          real.gr  Τσουκαλάς: «Στάχτη στα μάτια των πολιτών η πρό...
# 9997  web   prismaradio.gr  Κουτσούμπας κατά ΠΑΣΟΚ: Ράβει κοστούμι συγκυβέ...
# 9998  web           cnn.gr  Λωρίδα της Γάζας: Σχεδόν 180.000 άτομα εκτοπίσ...
# 9999  web           cnn.gr  Το Ουκρανικό κυριάρχησε στο τετ α τετ Λαβρόφ -...
#
# ...
