# %% [markdown]
# <a href="https://colab.research.google.com/github/medleutuoa/PythonEx1/blob/main/%CE%91%CE%BD%CF%84%CE%AF%CE%B3%CF%81%CE%B1%CF%86%CE%BF_exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Φτιάξτε ένα σύνολο δεδομένων με πληροφορίες για 3 άρθρα από ένα δημοσιογραφικό site της επιλογής σας.
#
# Οι πληροφορίες για κάθε άρθρο, θα είναι:
# - τίτλος του άρθρου
# - url του άρθρου
# - συντάκτης του άρθρου
# - θεματική κατηγορία άρθρου
# - ημερομηνία δημοσίευσης του άρθρου
#
# Οι πληροφορίες για κάθε άρθρο θα τοποθετηθούν σε ένα λεξικό.
#
# Το σύνολο των δεδομένων της αρθρογραφίας των 3 άρθρων θα είναι μια λίστα, η οποία θα περιέχει τα 3 λεξικά.
#
# **Παράδειγμα λεξικού (dictionary) με πληροφορίες για ένα άρθρο**:
# ```
# articleD_1 = {
#   "title": "Συναγερμός για κρούσμα κροτωνογενούς εγκεφαλίτιδας στην Ελλάδα – Εγκύκλιος ΕΟΔΥ",
#   "url": "https://www.news247.gr/ygeia/sinagermos-gia-krousma-krotonogenous-egkefalitidas-stin-ellada-egkiklios-eodi/",
#   "author": "ΓΙΑΝΝΗΣ ΔΕΒΕΤΖΟΓΛΟΥ",
#   "section": "Υγεία",
#   "date": "27 Μαρτίου 2025 13:40"
# }
# ```
#
# **Hints & Tips:**
# - αρχικά μπορείτε να δημιουργήσετε μια κενή λίστα με όνομα π.χ. "articlesL"
# - στη συνέχεια μπορείτε να δημιουργείτε ένα-ένα τα λεξικά με τις πληροφορίες για τα άρθρα (όπως στο παραπάνω παράδειγμα) και
# - να προσθέτε ένα-ένα τα λεξικά στη λίστα με append()
# - τέλος, καλέστε τη λίστα των άρθρων με το όνομά της για να εμφανιστεί στην οθόνη (μπορείτε να την κάνετε και print για να δείτε τη διαφορά στον τρόπο που εμφανίζεται η λίστα στην οθόνη)

# %%
articlesL = []
articleD_1 = {"title": "Κι όμως, τα υποκατάστατα ζάχαρης δείχνουν να αυξάνουν την όρεξη",
              "url" : "https://www.in.gr/2025/03/28/health/ki-omos-ta-ypokatastata-tis-zaxaris-deixnoun-na-ayksanoun-tin-oreksi/",
              "author" : "Θεοδώρα Ν. Τσώλη",
              "section" : "Υγεία",
              "date" : "28 Μαρτίου 2025 10:33"
               }
articleD_2 = {"title" : "Τέμπη: Στον Δημόκριτο αναζητά απαντήσεις για την πυρόσφαιρα ο ΕΟΔΑΣΑΑΜ",
              "url" : "https://www.naftemporiki.gr/politics/1938740/ch-doykas-kata-n-androylaki-gia-tin-parapompi-mpatzeli/",
              "author" : "in.gr Team",
              "section" : "Ελλάδα",
              "date" : "29 Μαρτίου 2025 15:05"
              }
articleD_3 = {"title" : "Αναδρομικά: Πώς θα δηλωθούν στην εφορία – Οι κρυφές παγίδες",
              "url" : "https://www.in.gr/2025/03/29/greece/tempi-ston-dimokrito-anazita-apantiseis-gia-tin-pyrosfaira-o-eodasaam/",
              "author" : "in.gr Team",
             "section" : "Οικονομικές Ειδήσεις",
              "date" : "29 Μαρτίου 2025 14:00"
              }
articlesL.append(articleD_1)
articlesL.append(articleD_2)
articlesL.append(articleD_3)
articlesL
# Out:
# [{'title': 'Κι όμως, τα υποκατάστατα ζάχαρης δείχνουν να αυξάνουν την όρεξη',
#   'url': 'https://www.in.gr/2025/03/28/health/ki-omos-ta-ypokatastata-tis-zaxaris-deixnoun-na-ayksanoun-tin-oreksi/',
#   'author': 'Θεοδώρα Ν. Τσώλη',
#   'section': 'Υγεία',
#   'date': '28 Μαρτίου 2025 10:33'},
#  {'title': 'Τέμπη: Στον Δημόκριτο αναζητά απαντήσεις για την πυρόσφαιρα ο ΕΟΔΑΣΑΑΜ',
#   'url': 'https://www.naftemporiki.gr/politics/1938740/ch-doykas-kata-n-androylaki-gia-tin-parapompi-mpatzeli/',
#   'author': 'in.gr Team',
#   'section': 'Ελλάδα',
#   'date': '29 Μαρτίου 2025 15:05'},
#  {'title': 'Αναδρομικά: Πώς θα δηλωθούν στην εφορία – Οι κρυφές παγίδες',
#   'url': 'https://www.in.gr/2025/03/29/greece/tempi-ston-dimokrito-anazita-apantiseis-gia-tin-pyrosfaira-o-eodasaam/',
#   'author': 'in.gr Team',
#   'section': 'Οικονομικές Ειδήσεις',
#   'date': '29 Μαρτίου 2025 14:00'}]

# %%
print(articlesL)
# Out:
# [{'title': 'Κι όμως, τα υποκατάστατα ζάχαρης δείχνουν να αυξάνουν την όρεξη', 'url': 'https://www.in.gr/2025/03/28/health/ki-omos-ta-ypokatastata-tis-zaxaris-deixnoun-na-ayksanoun-tin-oreksi/', 'author': 'Θεοδώρα Ν. Τσώλη', 'section': 'Υγεία', 'date': '28 Μαρτίου 2025 10:33'}, {'title': 'Τέμπη: Στον Δημόκριτο αναζητά απαντήσεις για την πυρόσφαιρα ο ΕΟΔΑΣΑΑΜ', 'url': 'https://www.naftemporiki.gr/politics/1938740/ch-doykas-kata-n-androylaki-gia-tin-parapompi-mpatzeli/', 'author': 'in.gr Team', 'section': 'Ελλάδα', 'date': '29 Μαρτίου 2025 15:05'}, {'title': 'Αναδρομικά: Πώς θα δηλωθούν στην εφορία – Οι κρυφές παγίδες', 'url': 'https://www.in.gr/2025/03/29/greece/tempi-ston-dimokrito-anazita-apantiseis-gia-tin-pyrosfaira-o-eodasaam/', 'author': 'in.gr Team', 'section': 'Οικονομικές Ειδήσεις', 'date': '29 Μαρτίου 2025 14:00'}]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Μετατρέψτε τη λίστα με τα λεξικά που φτιάξατε στην προηγούμενη άσκηση σε pandas dataframe.
#
# **Hints & Tips:**
# - Εισάγετε τη βιβλιοθήκη pandas με την εντολή ```import pandas as pd```
# - Δημιουργήστε ένα dataframe με όνομα ```df```, με την εντολή ```df = pd.DataFrame(articlesL)```
# - Καλέστε το df για να εμφανιστεί στην οθόνη

# %%
import pandas as pd
df = pd.DataFrame(articlesL)
df
# Out:
#                                                title  \
# 0  Κι όμως, τα υποκατάστατα ζάχαρης δείχνουν να α...
# 1  Τέμπη: Στον Δημόκριτο αναζητά απαντήσεις για τ...
# 2  Αναδρομικά: Πώς θα δηλωθούν στην εφορία – Οι κ...
#
#                                                  url            author  \
# 0  https://www.in.gr/2025/03/28/health/ki-omos-ta...  Θεοδώρα Ν. Τσώλη
# 1  https://www.naftemporiki.gr/politics/1938740/c...        in.gr Team
# 2  https://www.in.gr/2025/03/29/greece/tempi-ston...        in.gr Team
#
#                 section                   date
# 0                 Υγεία  28 Μαρτίου 2025 10:33
# 1                Ελλάδα  29 Μαρτίου 2025 15:05
# 2  Οικονομικές Ειδήσεις  29 Μαρτίου 2025 14:00

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
import pandas as pd

covid_df = pd.read_csv("")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 471245     Zimbabwe  2025-02-26        0.0       266410         0.0
# 471246     Zimbabwe  2025-02-27        0.0       266410         0.0
# 471247     Zimbabwe  2025-02-28        0.0       266410         0.0
# 471248     Zimbabwe  2025-03-01        0.0       266410         0.0
# 471249     Zimbabwe  2025-03-02        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 471245          5740           0.0            0.0                      NaN
# 471246          5740           0.0            0.0                      NaN
# 471247          5740           0.0            0.0                      NaN
# 471248          5740           0.0            0.0                      NaN
# 471249          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 471245                       NaN  ...       2.154574             NaN
# 471246                       NaN  ...       2.154574             NaN
# 471247                       NaN  ...       2.154574             NaN
# 471248                       NaN  ...       2.154574             NaN
# 471249                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 471245                      1737.0                     1819.0
# 471246                      1738.0                     1820.0
# 471247                      1739.0                     1821.0
# 471248                      1740.0                     1822.0
# 471249                      1741.0                     1823.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 471245                                1779.0
# 471246                                1780.0
# 471247                                1781.0
# 471248                                1782.0
# 471249                                1783.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 471245                                   1819.0
# 471246                                   1820.0
# 471247                                   1821.0
# 471248                                   1822.0
# 471249                                   1823.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 471245                                 1737.0                   0.0
# 471246                                 1738.0                   0.0
# 471247                                 1739.0                   0.0
# 471248                                 1740.0                   0.0
# 471249                                 1741.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 471245                            0.0                               0.0
# 471246                            0.0                               0.0
# 471247                            0.0                               0.0
# 471248                            0.0                               0.0
# 471249                            0.0                               0.0
#
# [471250 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
import pandas as pd
CoVac_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/compact/compact.csv")
CoVac_df
# Out:
#             country        date  total_cases  new_cases  new_cases_smoothed  \
# 0       Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1       Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2       Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3       Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4       Afghanistan  2020-01-05          0.0        0.0                 NaN
# ...             ...         ...          ...        ...                 ...
# 488431     Zimbabwe  2025-03-12     266410.0        0.0                 0.0
# 488432     Zimbabwe  2025-03-13     266410.0        0.0                 0.0
# 488433     Zimbabwe  2025-03-14     266410.0        0.0                 0.0
# 488434     Zimbabwe  2025-03-15     266410.0        0.0                 0.0
# 488435     Zimbabwe  2025-03-16     266410.0        0.0                 0.0
#
#         total_cases_per_million  new_cases_per_million  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                         0.000                    0.0
# 4                         0.000                    0.0
# ...                         ...                    ...
# 488431                16579.064                    0.0
# 488432                16579.064                    0.0
# 488433                16579.064                    0.0
# 488434                16579.064                    0.0
# 488435                16579.064                    0.0
#
#         new_cases_smoothed_per_million  total_deaths  new_deaths  ...  \
# 0                                  NaN           NaN         NaN  ...
# 1                                  NaN           NaN         NaN  ...
# 2                                  NaN           NaN         NaN  ...
# 3                                  NaN           0.0         0.0  ...
# 4                                  NaN           0.0         0.0  ...
# ...                                ...           ...         ...  ...
# 488431                             0.0        5740.0         0.0  ...
# 488432                             0.0        5740.0         0.0  ...
# 488433                             0.0        5740.0         0.0  ...
# 488434                             0.0        5740.0         0.0  ...
# 488435                             0.0        5740.0         0.0  ...
#
#         population  population_density  median_age  life_expectancy  \
# 0       40578846.0           62.215546      16.752              NaN
# 1       40578846.0           62.215546      16.752              NaN
# 2       40578846.0           62.215546      16.752              NaN
# 3       40578846.0           62.215546      16.752              NaN
# 4       40578846.0           62.215546      16.752              NaN
# ...            ...                 ...         ...              ...
# 488431  16069061.0           41.538223      17.683              NaN
# 488432  16069061.0           41.538223      17.683              NaN
# 488433  16069061.0           41.538223      17.683              NaN
# 488434  16069061.0           41.538223      17.683              NaN
# 488435  16069061.0           41.538223      17.683              NaN
#
#         gdp_per_capita  extreme_poverty  diabetes_prevalence  \
# 0            1516.2733              NaN                 10.9
# 1            1516.2733              NaN                 10.9
# 2            1516.2733              NaN                 10.9
# 3            1516.2733              NaN                 10.9
# 4            1516.2733              NaN                 10.9
# ...                ...              ...                  ...
# 488431       2207.9570         39.75453                  2.1
# 488432       2207.9570         39.75453                  2.1
# 488433       2207.9570         39.75453                  2.1
# 488434       2207.9570         39.75453                  2.1
# 488435       2207.9570         39.75453                  2.1
#
#         handwashing_facilities  hospital_beds_per_thousand  \
# 0                    48.214695                        0.39
# 1                    48.214695                        0.39
# 2                    48.214695                        0.39
# 3                    48.214695                        0.39
# 4                    48.214695                        0.39
# ...                        ...                         ...
# 488431               42.456093                        1.70
# 488432               42.456093                        1.70
# 488433               42.456093                        1.70
# 488434               42.456093                        1.70
# 488435               42.456093                        1.70
#
#         human_development_index
# 0                         0.462
# 1                         0.462
# 2                         0.462
# 3                         0.462
# 4                         0.462
# ...                         ...
# 488431                    0.550
# 488432                    0.550
# 488433                    0.550
# 488434                    0.550
# 488435                    0.550
#
# [488436 rows x 61 columns]
